# %%
from statistics import correlation

import pandas as pd
from PIL.ImageChops import offset
from matplotlib.pyplot import errorbar
from pandas.core.interchange.dataframe_protocol import DataFrame
from pandas.plotting import hist_frame

df = pd.read_csv("../data/ObesityDataSet_raw_and_data_sinthetic.csv")
df
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
#      FAVC  FCVC  NCP       CAEC SMOKE      CH2O  SCC       FAF       TUE  \
# 0      no   2.0  3.0  Sometimes    no  2.000000   no  0.000000  1.000000
# 1      no   3.0  3.0  Sometimes   yes  3.000000  yes  3.000000  0.000000
# 2      no   2.0  3.0  Sometimes    no  2.000000   no  2.000000  1.000000
# 3      no   3.0  3.0  Sometimes    no  2.000000   no  2.000000  0.000000
# 4      no   2.0  1.0  Sometimes    no  2.000000   no  0.000000  0.000000
# ...   ...   ...  ...        ...   ...       ...  ...       ...       ...
# 2106  yes   3.0  3.0  Sometimes    no  1.728139   no  1.676269  0.906247
# 2107  yes   3.0  3.0  Sometimes    no  2.005130   no  1.341390  0.599270
# 2108  yes   3.0  3.0  Sometimes    no  2.054193   no  1.414209  0.646288
# 2109  yes   3.0  3.0  Sometimes    no  2.852339   no  1.139107  0.586035
# 2110  yes   3.0  3.0  Sometimes    no  2.863513   no  1.026452  0.714137
#
#             CALC                 MTRANS           NObeyesdad
# 0             no  Public_Transportation        Normal_Weight
# 1      Sometimes  Public_Transportation        Normal_Weight
# 2     Frequently  Public_Transportation        Normal_Weight
# 3     Frequently                Walking   Overweight_Level_I
# 4      Sometimes  Public_Transportation  Overweight_Level_II
# ...          ...                    ...                  ...
# 2106   Sometimes  Public_Transportation     Obesity_Type_III
# 2107   Sometimes  Public_Transportation     Obesity_Type_III
# 2108   Sometimes  Public_Transportation     Obesity_Type_III
# 2109   Sometimes  Public_Transportation     Obesity_Type_III
# 2110   Sometimes  Public_Transportation     Obesity_Type_III
#
# [2111 rows x 17 columns]

# %% [markdown]
# # na 3

# %%
numerical: pd.DataFrame = df.select_dtypes(exclude=object)
categorical: pd.DataFrame = df.select_dtypes(include=object)

# %%
num_summary: pd.DataFrame = numerical.describe(percentiles=[0.05,0.95]).loc[['mean','50%','min','max','std','5%','95%']]
num_summary.loc['missing'] = numerical.isna().sum()

num_summary
# Out:
#                Age    Height      Weight      FCVC       NCP      CH2O  \
# mean     24.312600  1.701677   86.586058  2.419043  2.685628  2.008011
# 50%      22.777890  1.700499   83.000000  2.385502  3.000000  2.000000
# min      14.000000  1.450000   39.000000  1.000000  1.000000  1.000000
# max      61.000000  1.980000  173.000000  3.000000  4.000000  3.000000
# std       6.345968  0.093305   26.191172  0.533927  0.778039  0.612953
# 5%       17.891428  1.548291   48.500000  1.523214  1.000000  1.000000
# 95%      38.098070  1.850000  131.916152  3.000000  3.750881  3.000000
# missing   0.000000  0.000000    0.000000  0.000000  0.000000  0.000000
#
#               FAF       TUE
# mean     1.010298  0.657866
# 50%      1.000000  0.625350
# min      0.000000  0.000000
# max      3.000000  2.000000
# std      0.850592  0.608927
# 5%       0.000000  0.000000
# 95%      2.677133  2.000000
# missing  0.000000  0.000000

# %%
cat_summary = pd.DataFrame(columns=categorical.columns)
cat_summary.loc['missing'] = categorical.isna().sum()

cat_summary.loc['unique classes'] = categorical.nunique()

for col in categorical.columns:
    proportions = categorical[col].value_counts(normalize=True)
    for idx, value in proportions.items():
        cat_summary.loc[f'{idx}_proportion', col] = value

cat_summary
# Out:
#                                     Gender  family_history_with_overweight  \
# missing                           0.000000                        0.000000
# unique classes                    2.000000                        2.000000
# Male_proportion                   0.505921                             NaN
# Female_proportion                 0.494079                             NaN
# yes_proportion                         NaN                        0.817622
# no_proportion                          NaN                        0.182378
# Sometimes_proportion                   NaN                             NaN
# Frequently_proportion                  NaN                             NaN
# Always_proportion                      NaN                             NaN
# Public_Transportation_proportion       NaN                             NaN
# Automobile_proportion                  NaN                             NaN
# Walking_proportion                     NaN                             NaN
# Motorbike_proportion                   NaN                             NaN
# Bike_proportion                        NaN                             NaN
# Obesity_Type_I_proportion              NaN                             NaN
# Obesity_Type_III_proportion            NaN                             NaN
# Obesity_Type_II_proportion             NaN                             NaN
# Overweight_Level_I_proportion          NaN                             NaN
# Overweight_Level_II_proportion         NaN                             NaN
# Normal_Weight_proportion               NaN                             NaN
# Insufficient_Weight_proportion         NaN                             NaN
#
#                                       FAVC      CAEC     SMOKE       SCC  \
# missing                           0.000000  0.000000  0.000000  0.000000
# unique classes                    2.000000  4.000000  2.000000  2.000000
# Male_proportion                        NaN       NaN       NaN       NaN
# Female_proportion                      NaN       NaN       NaN       NaN
# yes_proportion                    0.883941       NaN  0.020843  0.045476
# no_proportion                     0.116059  0.024159  0.979157  0.954524
# Sometimes_proportion                   NaN  0.836097       NaN       NaN
# Frequently_proportion                  NaN  0.114638       NaN       NaN
# Always_proportion                      NaN  0.025107       NaN       NaN
# Public_Transportation_proportion       NaN       NaN       NaN       NaN
# Automobile_proportion                  NaN       NaN       NaN       NaN
# Walking_proportion                     NaN       NaN       NaN       NaN
# Motorbike_proportion                   NaN       NaN       NaN       NaN
# Bike_proportion                        NaN       NaN       NaN       NaN
# Obesity_Type_I_proportion              NaN       NaN       NaN       NaN
# Obesity_Type_III_proportion            NaN       NaN       NaN       NaN
# Obesity_Type_II_proportion             NaN       NaN       NaN       NaN
# Overweight_Level_I_proportion          NaN       NaN       NaN       NaN
# Overweight_Level_II_proportion         NaN       NaN       NaN       NaN
# Normal_Weight_proportion               NaN       NaN       NaN       NaN
# Insufficient_Weight_proportion         NaN       NaN       NaN       NaN
#
#                                       CALC    MTRANS  NObeyesdad
# missing                           0.000000  0.000000    0.000000
# unique classes                    4.000000  5.000000    7.000000
# Male_proportion                        NaN       NaN         NaN
# Female_proportion                      NaN       NaN         NaN
# yes_proportion                         NaN       NaN         NaN
# no_proportion                     0.302700       NaN         NaN
# Sometimes_proportion              0.663667       NaN         NaN
# Frequently_proportion             0.033160       NaN         NaN
# Always_proportion                 0.000474       NaN         NaN
# Public_Transportation_proportion       NaN  0.748460         NaN
# Automobile_proportion                  NaN  0.216485         NaN
# Walking_proportion                     NaN  0.026528         NaN
# Motorbike_proportion                   NaN  0.005211         NaN
# Bike_proportion                        NaN  0.003316         NaN
# Obesity_Type_I_proportion              NaN       NaN    0.166272
# Obesity_Type_III_proportion            NaN       NaN    0.153482
# Obesity_Type_II_proportion             NaN       NaN    0.140692
# Overweight_Level_I_proportion          NaN       NaN    0.137376
# Overweight_Level_II_proportion         NaN       NaN    0.137376
# Normal_Weight_proportion               NaN       NaN    0.135955
# Insufficient_Weight_proportion         NaN       NaN    0.128849

# %% [markdown]
# # na 3.5

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for col in numerical:
    plt.figure(figsize=(16,5))
    sns.boxplot(x='NObeyesdad',y=col,data=df)
    plt.show()

# %%
for col in numerical:
    plt.figure(figsize=(16,5))
    sns.violinplot(x='NObeyesdad',y=col,data=df)
    plt.show()

# %% [markdown]
# # na 4

# %%
for col in numerical:
    plt.figure(figsize=(12,4))

    sns.pointplot(x='NObeyesdad', y=col, data=df, errorbar="se", linestyles='none')

    plt.show()

# %%
for col in numerical:
    plt.figure(figsize=(12,4))

    sns.pointplot(x='NObeyesdad', y=col, data=df, errorbar="sd", linestyles='none')

    plt.show()

# %%
for col in numerical:
    sns.histplot(data=numerical, x=col)

    plt.title(f"{col} histogram")

    plt.show()

# %% [markdown]
# # na 4.5

# %%
sns.heatmap(numerical.corr(), annot=True, cmap="Greens")
# Out:
# <Axes: >

# %% [markdown]
# # na 5

# %%
for col in numerical:
    for col1 in numerical:
        if col is col1:
            continue

        if abs(numerical[col].corr(numerical[col1])) >= 0.2:
            plt.figure(figsize=(10,6))
            sns.regplot(x=col,y=col1,data=numerical, line_kws={"color": "Black"})
            plt.title(f"{col} x {col1}")
            plt.show()
